# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import os
import h5py

# %%
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import train_test_split
# tf.config.run_functions_eagerly(False)
import random
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780389344.961807    4529 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Set GPU

# %%
import tensorflow as tf #Buil model machine learning
import matplotlib.pyplot as plt
import pickle as pkl
import os
# tf.compat.v1.set_random_seed(1)

#Check GPU is using
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
if gpus: #nếu có gpu
    try:
#         chọn 1 số cái visible
        tf.config.experimental.set_visible_devices(gpus[1], 'GPU') # gpus[index]
        
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# 2 Physical GPUs, 1 Logical GPUs
# I0000 00:00:1780389392.746995    4529 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9055 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:41:00.0, compute capability: 7.5

# %% [markdown]
# # Preprocessing data

# %%
data_path = 'Data'
save_path = 'Save_model/TestModel'
dir_list = ['CORONA', 'FLOATING', 'VOID', 'PARTICLE', 'NEW_NOISE']

# %%
test_ratio = 0.1
unlab_ratio = 0.80
ratio_change = 0.25

# %%
list_all_data = {}

for dir_name in dir_list:
    list_raw_array = []

    dir_name_full = os.path.join(data_path, dir_name)
    for file_name in os.listdir(dir_name_full):
        # if '.csv' in file_name:
        if file_name.endswith('.csv'):
            raw_df = pd.read_csv(os.path.join(dir_name_full, file_name), sep = ',', header = None)
            raw_array = raw_df.values
            raw_array_tensor = tf.convert_to_tensor(raw_array)
            raw_array_reshape = tf.reshape(raw_array_tensor, (3600, 128))
            list_raw_array.append(raw_array_reshape)
        
        list_all_data[dir_name] = list_raw_array

# %%
for dir_name in dir_list:
    print(dir_name, len(list_all_data[dir_name]))
# Out:
# CORONA 94
# FLOATING 35
# VOID 242
# PARTICLE 66
# NEW_NOISE 298

# %%
X_train = []
y_train = []
X_test = []
y_test = []
X_unlab = []
X_full = []
y_full = []
for i in range(len(dir_list)):
    key = dir_list[i]
    print(key)
    
    fault = list_all_data[key]
    random.shuffle(fault)
    test_amount = int(test_ratio * len(fault))
    
    test_dataset_amount = fault[:test_amount]
    train_dataset_amount = fault[test_amount:]
    # test_dataset = np.array(test_dataset_amount)
    # train_dataset = np.array(train_dataset_amount)
    test_dataset = np.concatenate([np.array(item) for item in test_dataset_amount], axis=0)
    train_dataset = np.concatenate([np.array(item) for item in train_dataset_amount], axis=0)
    

    unlab_amount = int(unlab_ratio * train_dataset.shape[0])
    unlab_train = np.array(train_dataset_amount[:unlab_amount])
    X_lab_train = np.array(train_dataset_amount[unlab_amount:])
    
    print(f"Test set ", test_dataset.shape)
    print(f"Train set", X_lab_train.shape)
    

    lab_train = np.full(X_lab_train.shape[0],i,dtype='uint8')
    lab_test = np.full(test_dataset.shape[0],i, dtype='uint8')
   
    y_onehot_train = np.eye(5)[lab_train]
    y_onehot_test = np.eye(5)[lab_test]



    X_train.append(X_lab_train)
    X_unlab.append(unlab_train)
    y_train.append(y_onehot_train)
    X_test.append(test_dataset)
    y_test.append(y_onehot_test)


combined_X_train = np.concatenate(X_train, axis =0)
print(f"------Total train", combined_X_train.shape)

combined_X_unlab = np.concatenate(X_unlab, axis =0)
print(f"------Total unlabel train", combined_X_unlab.shape)

combined_label_train= np.concatenate(y_train, axis =0)
print(f"------Total label train", combined_label_train.shape)

combined_X_test = np.concatenate(X_test, axis =0)
print(f"______Total test", combined_X_test.shape)

combined_label_test = np.concatenate(y_test,axis =0)
print(f"______Total label test", combined_label_test.shape)
# Out:
# CORONA
# Test set  (32400, 128)
# Train set (0,)
# FLOATING
# Test set  (10800, 128)
# Train set (0,)
# VOID
# Test set  (86400, 128)
# Train set (0,)
# PARTICLE
# Test set  (21600, 128)
# Train set (0,)
# NEW_NOISE
# Test set  (104400, 128)
# Train set (0,)
# ------Total train (0,)
# ------Total unlabel train (664, 3600, 128)
# ------Total label train (0, 5)
# ______Total test (255600, 128)
# ______Total label test (255600, 5)

# %%
class DefaultDataset(tf.data.Dataset):
    def __init__(self, X, Y):
        self.X = X
        self.Y = Y
        assert len(self.X) == len(self.Y)
    def __len__(self):
        return len(self.X)
    def __getitem__(self, index):
        _x = self.X[index]
        _y = self.Y[index]
        return _x, _y

# %% [markdown]
# # Data Augmentation

# %%
# Scale noise following Gaussian distribution
def scale_noise(X):
    mu, sigma = 1.0, 0.01
    noise = tf.random.normal(shape=tf.shape(X), mean=mu, stddev=sigma, dtype= tf.float32)
    X = tf.cast(X, dtype=tf.float32) * noise
    # noise = np.random.normal(mu,sigma,X.shape)
    # X = X * noise
    return X

# %%
import random
def random_crop(X):
    X = tf.convert_to_tensor(X)  # Convert X to a TensorFlow tensor
    non_zero_indices = tf.where(tf.not_equal(X, 0))

    # Calculate the number of non-zero elements in X
    num_non_zero = tf.shape(non_zero_indices)[0]

    # Calculate the number of elements to replace (10% of non-zero elements)
    num_to_replace = tf.cast(tf.round(tf.cast(num_non_zero, dtype=tf.float32) * 0.1), dtype=tf.int32)

    # Ensure num_to_replace is at least 1
    num_to_replace = tf.maximum(num_to_replace, 1)

    # Randomly select 'num_to_replace' indices to change to zero
    shuffled_indices = tf.random.shuffle(non_zero_indices)
    indices_to_replace = shuffled_indices[:num_to_replace]

    # Create the updates tensor with the same shape as indices_to_replace
    updates = tf.zeros([num_to_replace], dtype=X.dtype)

    # Set the selected non-zero elements to zero
    X = tf.tensor_scatter_nd_update(X, indices_to_replace, updates)

    return X

# %% [markdown]
# # Hyparameters for the algorithm

# %%
# EPOCHS = 200
EPOCHS = 20
TEMPERATURE = 0.1
SEED = 42 # the embeddings during training to improve the contrastive loss function.
AUTO = tf.data.AUTOTUNE
LEARNING_RATE = 0.0001
WEIGHT_DECAY = 0.0005

# %% [markdown]
# # Calculate the batch sizes for labeled and unlabeled samples

# %%
X_label_tensor = tf.convert_to_tensor(combined_X_train)
X_label_tensor.shape
# Out:
# TensorShape([0])

# %%
# Convert the raw unlabeled data directly to a tensor.
# The random_crop and scale_noise augmentations will be handled
# on-the-fly inside FixMatch.train_step.
# x_unlabeled_train = tf.convert_to_tensor(combined_X_unlab, dtype=tf.float32)

# print("Unlabeled train tensor shape:", x_unlabeled_train.shape)
# Out:
# Unlabeled train tensor shape: (664, 3600, 128)

# %%
X_unlab_aug = scale_noise(combined_X_unlab)
print(X_unlab_aug.shape)

X_ulb_scale_tensor = tf.convert_to_tensor(X_unlab_aug)
print(type(X_ulb_scale_tensor))

X_unlab_change = random_crop(combined_X_unlab)
print(X_unlab_aug.shape)

X_ulb_change_tensor = tf.convert_to_tensor(X_unlab_change)
print(type(X_ulb_change_tensor))
# Out:
# W0000 00:00:1780389715.603987    4529 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.14GiB (rounded to 1223884800)requested by op Cast
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# I0000 00:00:1780389715.604496    4529 bfc_allocator.cc:1049] BFCAllocator dump for GPU_0_bfc
# I0000 00:00:1780389715.604504    4529 bfc_allocator.cc:1056] Bin (256): 	Total Chunks: 25, Chunks in use: 25. 6.2KiB allocated for chunks. 6.2KiB in use in bin. 505B client-requested in use in bin.
# I0000 00:00:1780389715.604512    4529 bfc_allocator.cc:1056] Bin (512): 	Total Chunks: 1, Chunks in use: 1. 768B allocated for chunks. 768B in use in bin. 576B client-requested in use in bin.
# I0000 00:00:1780389715.604516    4529 bfc_allocator.cc:1056] Bin (1024): 	Total Chunks: 2, Chunks in use: 2. 2.5KiB allocated for chunks. 2.5KiB in use in bin. 2.3KiB client-requested in use in bin.
# I0000 00:00:1780389715.604520    4529 bfc_allocator.cc:1056] Bin (2048): 	Total Chunks: 2, Chunks in use: 0. 6.5KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1780389715.604524    4529 bfc_allocator.cc:1056] Bin (4096): 	Total Chunks: 1, Chunks in use: 1. 4.5KiB allocated for chunks. 4.5KiB in use in bin. 4.5KiB client-requested in use in bin.
# I0000 00:00:1780389715.604529    4529 bfc_allocator.cc:1056] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1780389715.604532    4529 bfc_allocator.cc:1056] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1780389715.604536    4529 bfc_allocator.cc:1056] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1780389715.604539    4529 bfc_allocator.cc:1056] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1780389715.604543    4529 bfc_allocator.cc:1056] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1780389715.604547    4529 bfc_allocator.cc:1056] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1780389715.604550    4529 bfc_allocator.cc:1056] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1780389715.604554    4529 bfc_allocator.cc:1056] Bin (1048576): 	Total Chunks: 1, Chunks in use: 1. 1.95MiB allocated for chunks. 1.95MiB in use in bin. 1.95MiB client-requested in use in bin.
# I0000 00:00:1780389715.604558    4529 bfc_allocator.cc:1056] Bin (2097152): 	Total Chunks: 727, Chunks in use: 727. 2.50GiB allocated for chunks. 2.50GiB in use in bin. 2.50GiB client-requested in use in bin.
# I0000 00:00:1780389715.604562    4529 bfc_allocator.cc:1056] Bin (4194304): 	Total Chunks: 8, Chunks in use: 8. 39.73MiB allocated for chunks. 39.73MiB in use in bin. 28.12MiB client-requested in use in bin.
# I0000 00:00:1780389715.604566    4529 bfc_allocator.cc:1056] Bin (8388608): 	Total Chunks: 1, Chunks in use: 1. 9.75MiB allocated for chunks. 9.75MiB in use in bin. 9.75MiB client-requested in use in bin.
# I0000 00:00:1780389715.604570    4529 bfc_allocator.cc:1056] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1780389715.604573    4529 bfc_allocator.cc:1056] Bin (33554432): 	Total Chunks: 1, Chunks in use: 1. 56.25MiB allocated for chunks. 56.25MiB in use in bin. 56.25MiB client-requested in use in bin.
# I0000 00:00:1780389715.604578    4529 bfc_allocator.cc:1056] Bin (67108864): 	Total Chunks: 1, Chunks in use: 0. 112.50MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1780389715.604584    4529 bfc_allocator.cc:1056] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1780389715.604588    4529 bfc_allocator.cc:1056] Bin (268435456): 	Total Chunks: 5, Chunks in use: 4. 5.29GiB allocated for chunks. 4.88GiB in use in bin. 4.80GiB client-requested in use in bin.
# I0000 00:00:1780389715.604592    4529 bfc_allocator.cc:1072] Bin for 1.14GiB was 256.00MiB, Chunk State:
# I0000 00:00:1780389715.604595    4529 bfc_allocator.cc:1078]   Size: 413.97MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 1.14GiB | Requested Size: 1.14GiB | in_use: 1 | bin_num: -1
# I0000 00:00:1780389715.604603    4529 bfc_allocator.cc:1085] Next region of size 4194304
# I0000 00:00:1780389715.604608    4529 bfc_allocator.cc:1105] InUse at 1309600000 of size 4194304 next 18446744073709551615
# I0000 00:00:1780389715.604610    4529 bfc_allocator.cc:1085] Next region of size 4194304
# I0000 00:00:1780389715.604613    4529 bfc_allocator.cc:1105] InUse at 1309a00000 of size 1280 next 2
# I0000 00:00:1780389715.604616    4529 bfc_allocator.cc:1105] InUse at 1309a00500 of size 4193024 next 18446744073709551615
# I0000 00:00:1780389715.604618    4529 bfc_allocator.cc:1085] Next region of size 8388608
# I0000 00:00:1780389715.604621    4529 bfc_allocator.cc:1105] InUse at 1309e00000 of size 3686400 next 4
# I0000 00:00:1780389715.604624    4529 bfc_allocator.cc:1105] InUse at 130a184000 of size 4702208 next 18446744073709551615
# I0000 00:00:1780389715.604627    4529 bfc_allocator.cc:1085] Next region of size 16777216
# I0000 00:00:1780389715.604630    4529 bfc_allocator.cc:1105] InUse at 130a600000 of size 3686400 next 6
# I0000 00:00:1780389715.604632    4529 bfc_allocator.cc:1105] InUse at 130a984000 of size 3686400 next 7
# I0000 00:00:1780389715.604635    4529 bfc_allocator.cc:1105] InUse at 130ad08000 of size 3686400 next 8
# I0000 00:00:1780389715.604639    4529 bfc_allocator.cc:1105] InUse at 130b08c000 of size 5718016 next 18446744073709551615
# I0000 00:00:1780389715.604641    4529 bfc_allocator.cc:1085] Next region of size 33554432
# I0000 00:00:1780389715.604644    4529 bfc_allocator.cc:1105] InUse at 130b600000 of size 3686400 next 10
# I0000 00:00:1780389715.604647    4529 bfc_allocator.cc:1105] InUse at 130b984000 of size 3686400 next 11
# I0000 00:00:1780389715.604649    4529 bfc_allocator.cc:1105] InUse at 130bd08000 of size 3686400 next 12
# I0000 00:00:1780389715.604652    4529 bfc_allocator.cc:1105] InUse at 130c08c000 of size 3686400 next 13
# I0000 00:00:1780389715.604654    4529 bfc_allocator.cc:1105] InUse at 130c410000 of size 3686400 next 14
# I0000 00:00:1780389715.604657    4529 bfc_allocator.cc:1105] InUse at 130c794000 of size 3686400 next 15
# I0000 00:00:1780389715.604660    4529 bfc_allocator.cc:1105] InUse at 130cb18000 of size 3686400 next 16
# I0000 00:00:1780389715.604662    4529 bfc_allocator.cc:1105] InUse at 130ce9c000 of size 3686400 next 17
# I0000 00:00:1780389715.604665    4529 bfc_allocator.cc:1105] InUse at 130d220000 of size 4063232 next 18446744073709551615
# I0000 00:00:1780389715.604667    4529 bfc_allocator.cc:1085] Next region of size 67108864
# I0000 00:00:1780389715.604670    4529 bfc_allocator.cc:1105] InUse at 130d600000 of size 3686400 next 19
# I0000 00:00:1780389715.604673    4529 bfc_allocator.cc:1105] InUse at 130d984000 of size 3686400 next 20
# I0000 00:00:1780389715.604675    4529 bfc_allocator.cc:1105] InUse at 130dd08000 of size 3686400 next 21
# I0000 00:00:1780389715.604678    4529 bfc_allocator.cc:1105] InUse at 130e08c000 of size 3686400 next 22
# I0000 00:00:1780389715.604680    4529 bfc_allocator.cc:1105] InUse at 130e410000 of size 3686400 next 23
# I0000 00:00:1780389715.604683    4529 bfc_allocator.cc:1105] InUse at 130e794000 of size 3686400 next 24
# I0000 00:00:1780389715.604685    4529 bfc_allocator.cc:1105] InUse at 130eb18000 of size 3686400 next 25
# I0000 00:00:1780389715.604689    4529 bfc_allocator.cc:1105] InUse at 130ee9c000 of size 3686400 next 26
# I0000 00:00:1780389715.604691    4529 bfc_allocator.cc:1105] InUse at 130f220000 of size 3686400 next 27
# I0000 00:00:1780389715.604694    4529 bfc_allocator.cc:1105] InUse at 130f5a4000 of size 3686400 next 28
# I0000 00:00:1780389715.604696    4529 bfc_allocator.cc:1105] InUse at 130f928000 of size 3686400 next 29
# I0000 00:00:1780389715.604699    4529 bfc_allocator.cc:1105] InUse at 130fcac000 of size 3686400 next 30
# I0000 00:00:1780389715.604702    4529 bfc_allocator.cc:1105] InUse at 1310030000 of size 3686400 next 31
# I0000 00:00:1780389715.604704    4529 bfc_allocator.cc:1105] InUse at 13103b4000 of size 3686400 next 32
# I0000 00:00:1780389715.604707    4529 bfc_allocator.cc:1105] InUse at 1310738000 of size 3686400 next 33
# I0000 00:00:1780389715.604709    4529 bfc_allocator.cc:1105] InUse at 1310abc000 of size 3686400 next 34
# I0000 00:00:1780389715.604712    4529 bfc_allocator.cc:1105] InUse at 1310e40000 of size 3686400 next 35
# I0000 00:00:1780389715.604714    4529 bfc_allocator.cc:1105] InUse at 13111c4000 of size 4440064 next 18446744073709551615
# I0000 00:00:1780389715.604717    4529 bfc_allocator.cc:1085] Next region of size 134217728
# I0000 00:00:1780389715.604720    4529 bfc_allocator.cc:1105] InUse at 1311600000 of size 3686400 next 37
# I0000 00:00:1780389715.604722    4529 bfc_allocator.cc:1105] InUse at 1311984000 of size 3686400 next 38
# I0000 00:00:1780389715.604725    4529 bfc_allocator.cc:1105] InUse at 1311d08000 of size 3686400 next 39
# I0000 00:00:1780389715.604747    4529 bfc_allocator.cc:1105] InUse at 131208c000 of size 3686400 next 40
# I0000 00:00:1780389715.604751    4529 bfc_allocator.cc:1105] InUse at 1312410000 of size 3686400 next 41
# I0000 00:00:1780389715.604753    4529 bfc_allocator.cc:1105] InUse at 1312794000 of size 3686400 next 42
# I0000 00:00:1780389715.604756    4529 bfc_allocator.cc:1105] InUse at 1312b18000 of size 3686400 next 43
# I0000 00:00:1780389715.604758    4529 bfc_allocator.cc:1105] InUse at 1312e9c000 of size 3686400 next 44
# I0000 00:00:1780389715.604761    4529 bfc_allocator.cc:1105] InUse at 1313220000 of size 3686400 next 45
# I0000 00:00:1780389715.604763    4529 bfc_allocator.cc:1105] InUse at 13135a4000 of size 3686400 next 46
# I0000 00:00:1780389715.604766    4529 bfc_allocator.cc:1105] InUse at 1313928000 of size 3686400 next 47
# I0000 00:00:1780389715.604768    4529 bfc_allocator.cc:1105] InUse at 1313cac000 of size 3686400 next 48
# I0000 00:00:1780389715.604771    4529 bfc_allocator.cc:1105] InUse at 1314030000 of size 3686400 next 49
# I0000 00:00:1780389715.604773    4529 bfc_allocator.cc:1105] InUse at 13143b4000 of size 3686400 next 50
# I0000 00:00:1780389715.604776    4529 bfc_allocator.cc:1105] InUse at 1314738000 of size 3686400 next 51
# I0000 00:00:1780389715.604778    4529 bfc_allocator.cc:1105] InUse at 1314abc000 of size 3686400 next 52
# I0000 00:00:1780389715.604781    4529 bfc_allocator.cc:1105] InUse at 1314e40000 of size 3686400 next 53
# I0000 00:00:1780389715.604783    4529 bfc_allocator.cc:1105] InUse at 13151c4000 of size 3686400 next 54
# I0000 00:00:1780389715.604786    4529 bfc_allocator.cc:1105] InUse at 1315548000 of size 3686400 next 55
# I0000 00:00:1780389715.604788    4529 bfc_allocator.cc:1105] InUse at 13158cc000 of size 3686400 next 56
# I0000 00:00:1780389715.604791    4529 bfc_allocator.cc:1105] InUse at 1315c50000 of size 3686400 next 57
# I0000 00:00:1780389715.604793    4529 bfc_allocator.cc:1105] InUse at 1315fd4000 of size 3686400 next 58
# I0000 00:00:1780389715.604796    4529 bfc_allocator.cc:1105] InUse at 1316358000 of size 3686400 next 59
# I0000 00:00:1780389715.604798    4529 bfc_allocator.cc:1105] InUse at 13166dc000 of size 3686400 next 60
# I0000 00:00:1780389715.604801    4529 bfc_allocator.cc:1105] InUse at 1316a60000 of size 3686400 next 61
# I0000 00:00:1780389715.604804    4529 bfc_allocator.cc:1105] InUse at 1316de4000 of size 3686400 next 62
# I0000 00:00:1780389715.604808    4529 bfc_allocator.cc:1105] InUse at 1317168000 of size 3686400 next 63
# I0000 00:00:1780389715.604811    4529 bfc_allocator.cc:1105] InUse at 13174ec000 of size 3686400 next 64
# I0000 00:00:1780389715.604813    4529 bfc_allocator.cc:1105] InUse at 1317870000 of size 3686400 next 65
# I0000 00:00:1780389715.604816    4529 bfc_allocator.cc:1105] InUse at 1317bf4000 of size 3686400 next 66
# I0000 00:00:1780389715.604818    4529 bfc_allocator.cc:1105] InUse at 1317f78000 of size 3686400 next 67
# I0000 00:00:1780389715.604821    4529 bfc_allocator.cc:1105] InUse at 13182fc000 of size 3686400 next 68
# I0000 00:00:1780389715.604823    4529 bfc_allocator.cc:1105] InUse at 1318680000 of size 3686400 next 69
# I0000 00:00:1780389715.604826    4529 bfc_allocator.cc:1105] InUse at 1318a04000 of size 3686400 next 70
# I0000 00:00:1780389715.604828    4529 bfc_allocator.cc:1105] InUse at 1318d88000 of size 3686400 next 71
# I0000 00:00:1780389715.604831    4529 bfc_allocator.cc:1105] InUse at 131910c000 of size 5193728 next 18446744073709551615
# I0000 00:00:1780389715.604833    4529 bfc_allocator.cc:1085] Next region of size 268435456
# I0000 00:00:1780389715.604837    4529 bfc_allocator.cc:1105] InUse at 1319600000 of size 3686400 next 73
# I0000 00:00:1780389715.604839    4529 bfc_allocator.cc:1105] InUse at 1319984000 of size 3686400 next 74
# I0000 00:00:1780389715.604842    4529 bfc_allocator.cc:1105] InUse at 1319d08000 of size 3686400 next 75
# I0000 00:00:1780389715.604844    4529 bfc_allocator.cc:1105] InUse at 131a08c000 of size 3686400 next 76
# I0000 00:00:1780389715.604847    4529 bfc_allocator.cc:1105] InUse at 131a410000 of size 3686400 next 77
# I0000 00:00:1780389715.604850    4529 bfc_allocator.cc:1105] InUse at 131a794000 of size 3686400 next 78
# I0000 00:00:1780389715.604852    4529 bfc_allocator.cc:1105] InUse at 131ab18000 of size 3686400 next 79
# I0000 00:00:1780389715.604855    4529 bfc_allocator.cc:1105] InUse at 131ae9c000 of size 3686400 next 80
# I0000 00:00:1780389715.604857    4529 bfc_allocator.cc:1105] InUse at 131b220000 of size 3686400 next 81
# I0000 00:00:1780389715.604859    4529 bfc_allocator.cc:1105] InUse at 131b5a4000 of size 3686400 next 82
# I0000 00:00:1780389715.604862    4529 bfc_allocator.cc:1105] InUse at 131b928000 of size 3686400 next 83
# I0000 00:00:1780389715.604864    4529 bfc_allocator.cc:1105] InUse at 131bcac000 of size 3686400 next 84
# I0000 00:00:1780389715.604867    4529 bfc_allocator.cc:1105] InUse at 131c030000 of size 3686400 next 85
# I0000 00:00:1780389715.604869    4529 bfc_allocator.cc:1105] InUse at 131c3b4000 of size 3686400 next 86
# I0000 00:00:1780389715.604872    4529 bfc_allocator.cc:1105] InUse at 131c738000 of size 3686400 next 87
# I0000 00:00:1780389715.604874    4529 bfc_allocator.cc:1105] InUse at 131cabc000 of size 3686400 next 88
# I0000 00:00:1780389715.604877    4529 bfc_allocator.cc:1105] InUse at 131ce40000 of size 3686400 next 89
# I0000 00:00:1780389715.604880    4529 bfc_allocator.cc:1105] InUse at 131d1c4000 of size 3686400 next 90
# I0000 00:00:1780389715.604882    4529 bfc_allocator.cc:1105] InUse at 131d548000 of size 3686400 next 91
# I0000 00:00:1780389715.604885    4529 bfc_allocator.cc:1105] InUse at 131d8cc000 of size 3686400 next 92
# I0000 00:00:1780389715.604887    4529 bfc_allocator.cc:1105] InUse at 131dc50000 of size 3686400 next 93
# I0000 00:00:1780389715.604890    4529 bfc_allocator.cc:1105] InUse at 131dfd4000 of size 3686400 next 94
# I0000 00:00:1780389715.604892    4529 bfc_allocator.cc:1105] InUse at 131e358000 of size 3686400 next 95
# I0000 00:00:1780389715.604895    4529 bfc_allocator.cc:1105] InUse at 131e6dc000 of size 3686400 next 96
# I0000 00:00:1780389715.604897    4529 bfc_allocator.cc:1105] InUse at 131ea60000 of size 3686400 next 97
# I0000 00:00:1780389715.604900    4529 bfc_allocator.cc:1105] InUse at 131ede4000 of size 3686400 next 98
# I0000 00:00:1780389715.604902    4529 bfc_allocator.cc:1105] InUse at 131f168000 of size 3686400 next 99
# I0000 00:00:1780389715.604906    4529 bfc_allocator.cc:1105] InUse at 131f4ec000 of size 3686400 next 100
# I0000 00:00:1780389715.604909    4529 bfc_allocator.cc:1105] InUse at 131f870000 of size 3686400 next 101
# I0000 00:00:1780389715.604911    4529 bfc_allocator.cc:1105] InUse at 131fbf4000 of size 3686400 next 102
# I0000 00:00:1780389715.604914    4529 bfc_allocator.cc:1105] InUse at 131ff78000 of size 3686400 next 103
# I0000 00:00:1780389715.604916    4529 bfc_allocator.cc:1105] InUse at 13202fc000 of size 3686400 next 104
# I0000 00:00:1780389715.604919    4529 bfc_allocator.cc:1105] InUse at 1320680000 of size 3686400 next 105
# I0000 00:00:1780389715.604921    4529 bfc_allocator.cc:1105] InUse at 1320a04000 of size 3686400 next 106
# I0000 00:00:1780389715.604924    4529 bfc_allocator.cc:1105] InUse at 1320d88000 of size 3686400 next 107
# I0000 00:00:1780389715.604927    4529 bfc_allocator.cc:1105] InUse at 132110c000 of size 3686400 next 108
# I0000 00:00:1780389715.604929    4529 bfc_allocator.cc:1105] InUse at 1321490000 of size 3686400 next 109
# I0000 00:00:1780389715.604932    4529 bfc_allocator.cc:1105] InUse at 1321814000 of size 3686400 next 110
# I0000 00:00:1780389715.604934    4529 bfc_allocator.cc:1105] InUse at 1321b98000 of size 3686400 next 111
# I0000 00:00:1780389715.604936    4529 bfc_allocator.cc:1105] InUse at 1321f1c000 of size 3686400 next 112
# I0000 00:00:1780389715.604939    4529 bfc_allocator.cc:1105] InUse at 13222a0000 of size 3686400 next 113
# I0000 00:00:1780389715.604942    4529 bfc_allocator.cc:1105] InUse at 1322624000 of size 3686400 next 114
# I0000 00:00:1780389715.604944    4529 bfc_allocator.cc:1105] InUse at 13229a8000 of size 3686400 next 115
# I0000 00:00:1780389715.604947    4529 bfc_allocator.cc:1105] InUse at 1322d2c000 of size 3686400 next 116
# I0000 00:00:1780389715.604949    4529 bfc_allocator.cc:1105] InUse at 13230b0000 of size 3686400 next 117
# I0000 00:00:1780389715.604952    4529 bfc_allocator.cc:1105] InUse at 1323434000 of size 3686400 next 118
# I0000 00:00:1780389715.604954    4529 bfc_allocator.cc:1105] InUse at 13237b8000 of size 3686400 next 119
# I0000 00:00:1780389715.604957    4529 bfc_allocator.cc:1105] InUse at 1323b3c000 of size 3686400 next 120
# I0000 00:00:1780389715.604959    4529 bfc_allocator.cc:1105] InUse at 1323ec0000 of size 3686400 next 121
# I0000 00:00:1780389715.604962    4529 bfc_allocator.cc:1105] InUse at 1324244000 of size 3686400 next 122
# I0000 00:00:1780389715.604964    4529 bfc_allocator.cc:1105] InUse at 13245c8000 of size 3686400 next 123
# I0000 00:00:1780389715.604967    4529 bfc_allocator.cc:1105] InUse at 132494c000 of size 3686400 next 124
# I0000 00:00:1780389715.604969    4529 bfc_allocator.cc:1105] InUse at 1324cd0000 of size 3686400 next 125
# I0000 00:00:1780389715.604972    4529 bfc_allocator.cc:1105] InUse at 1325054000 of size 3686400 next 126
# I0000 00:00:1780389715.604974    4529 bfc_allocator.cc:1105] InUse at 13253d8000 of size 3686400 next 127
# I0000 00:00:1780389715.604977    4529 bfc_allocator.cc:1105] InUse at 132575c000 of size 3686400 next 128
# I0000 00:00:1780389715.604979    4529 bfc_allocator.cc:1105] InUse at 1325ae0000 of size 3686400 next 129
# I0000 00:00:1780389715.604982    4529 bfc_allocator.cc:1105] InUse at 1325e64000 of size 3686400 next 130
# I0000 00:00:1780389715.604984    4529 bfc_allocator.cc:1105] InUse at 13261e8000 of size 3686400 next 131
# I0000 00:00:1780389715.604987    4529 bfc_allocator.cc:1105] InUse at 132656c000 of size 3686400 next 132
# I0000 00:00:1780389715.604989    4529 bfc_allocator.cc:1105] InUse at 13268f0000 of size 3686400 next 133
# I0000 00:00:1780389715.604992    4529 bfc_allocator.cc:1105] InUse at 1326c74000 of size 3686400 next 134
# I0000 00:00:1780389715.604994    4529 bfc_allocator.cc:1105] InUse at 1326ff8000 of size 3686400 next 135
# I0000 00:00:1780389715.604997    4529 bfc_allocator.cc:1105] InUse at 132737c000 of size 3686400 next 136
# I0000 00:00:1780389715.604999    4529 bfc_allocator.cc:1105] InUse at 1327700000 of size 3686400 next 137
# I0000 00:00:1780389715.605003    4529 bfc_allocator.cc:1105] InUse at 1327a84000 of size 3686400 next 138
# I0000 00:00:1780389715.605005    4529 bfc_allocator.cc:1105] InUse at 1327e08000 of size 3686400 next 139
# I0000 00:00:1780389715.605008    4529 bfc_allocator.cc:1105] InUse at 132818c000 of size 3686400 next 140
# I0000 00:00:1780389715.605010    4529 bfc_allocator.cc:1105] InUse at 1328510000 of size 3686400 next 141
# I0000 00:00:1780389715.605013    4529 bfc_allocator.cc:1105] InUse at 1328894000 of size 3686400 next 142
# I0000 00:00:1780389715.605016    4529 bfc_allocator.cc:1105] InUse at 1328c18000 of size 3686400 next 143
# I0000 00:00:1780389715.605018    4529 bfc_allocator.cc:1105] InUse at 1328f9c000 of size 6701056 next 18446744073709551615
# I0000 00:00:1780389715.605021    4529 bfc_allocator.cc:1085] Next region of size 536870912
# I0000 00:00:1780389715.605024    4529 bfc_allocator.cc:1105] InUse at 1329600000 of size 3686400 next 145
# I0000 00:00:1780389715.605026    4529 bfc_allocator.cc:1105] InUse at 1329984000 of size 3686400 next 146
# I0000 00:00:1780389715.605029    4529 bfc_allocator.cc:1105] InUse at 1329d08000 of size 3686400 next 147
# I0000 00:00:1780389715.605031    4529 bfc_allocator.cc:1105] InUse at 132a08c000 of size 3686400 next 148
# I0000 00:00:1780389715.605034    4529 bfc_allocator.cc:1105] InUse at 132a410000 of size 3686400 next 149
# I0000 00:00:1780389715.605036    4529 bfc_allocator.cc:1105] InUse at 132a794000 of size 3686400 next 150
# I0000 00:00:1780389715.605039    4529 bfc_allocator.cc:1105] InUse at 132ab18000 of size 3686400 next 151
# I0000 00:00:1780389715.605041    4529 bfc_allocator.cc:1105] InUse at 132ae9c000 of size 3686400 next 152
# I0000 00:00:1780389715.605044    4529 bfc_allocator.cc:1105] InUse at 132b220000 of size 3686400 next 153
# I0000 00:00:1780389715.605046    4529 bfc_allocator.cc:1105] InUse at 132b5a4000 of size 3686400 next 154
# I0000 00:00:1780389715.605049    4529 bfc_allocator.cc:1105] InUse at 132b928000 of size 3686400 next 155
# I0000 00:00:1780389715.605051    4529 bfc_allocator.cc:1105] InUse at 132bcac000 of size 3686400 next 156
# I0000 00:00:1780389715.605054    4529 bfc_allocator.cc:1105] InUse at 132c030000 of size 3686400 next 157
# I0000 00:00:1780389715.605057    4529 bfc_allocator.cc:1105] InUse at 132c3b4000 of size 3686400 next 158
# I0000 00:00:1780389715.605060    4529 bfc_allocator.cc:1105] InUse at 132c738000 of size 3686400 next 159
# I0000 00:00:1780389715.605062    4529 bfc_allocator.cc:1105] InUse at 132cabc000 of size 3686400 next 160
# I0000 00:00:1780389715.605065    4529 bfc_allocator.cc:1105] InUse at 132ce40000 of size 3686400 next 161
# I0000 00:00:1780389715.605067    4529 bfc_allocator.cc:1105] InUse at 132d1c4000 of size 3686400 next 162
# I0000 00:00:1780389715.605070    4529 bfc_allocator.cc:1105] InUse at 132d548000 of size 3686400 next 163
# I0000 00:00:1780389715.605072    4529 bfc_allocator.cc:1105] InUse at 132d8cc000 of size 3686400 next 164
# I0000 00:00:1780389715.605075    4529 bfc_allocator.cc:1105] InUse at 132dc50000 of size 3686400 next 165
# I0000 00:00:1780389715.605077    4529 bfc_allocator.cc:1105] InUse at 132dfd4000 of size 3686400 next 166
# I0000 00:00:1780389715.605080    4529 bfc_allocator.cc:1105] InUse at 132e358000 of size 3686400 next 167
# I0000 00:00:1780389715.605082    4529 bfc_allocator.cc:1105] InUse at 132e6dc000 of size 3686400 next 168
# I0000 00:00:1780389715.605085    4529 bfc_allocator.cc:1105] InUse at 132ea60000 of size 3686400 next 169
# I0000 00:00:1780389715.605087    4529 bfc_allocator.cc:1105] InUse at 132ede4000 of size 3686400 next 170
# I0000 00:00:1780389715.605090    4529 bfc_allocator.cc:1105] InUse at 132f168000 of size 3686400 next 171
# I0000 00:00:1780389715.605092    4529 bfc_allocator.cc:1105] InUse at 132f4ec000 of size 3686400 next 172
# I0000 00:00:1780389715.605095    4529 bfc_allocator.cc:1105] InUse at 132f870000 of size 3686400 next 173
# I0000 00:00:1780389715.605097    4529 bfc_allocator.cc:1105] InUse at 132fbf4000 of size 3686400 next 174
# I0000 00:00:1780389715.605100    4529 bfc_allocator.cc:1105] InUse at 132ff78000 of size 3686400 next 175
# I0000 00:00:1780389715.605103    4529 bfc_allocator.cc:1105] InUse at 13302fc000 of size 3686400 next 176
# I0000 00:00:1780389715.605105    4529 bfc_allocator.cc:1105] InUse at 1330680000 of size 3686400 next 177
# I0000 00:00:1780389715.605108    4529 bfc_allocator.cc:1105] InUse at 1330a04000 of size 3686400 next 178
# I0000 00:00:1780389715.605110    4529 bfc_allocator.cc:1105] InUse at 1330d88000 of size 3686400 next 179
# I0000 00:00:1780389715.605113    4529 bfc_allocator.cc:1105] InUse at 133110c000 of size 3686400 next 180
# I0000 00:00:1780389715.605115    4529 bfc_allocator.cc:1105] InUse at 1331490000 of size 3686400 next 181
# I0000 00:00:1780389715.605118    4529 bfc_allocator.cc:1105] InUse at 1331814000 of size 3686400 next 182
# I0000 00:00:1780389715.605120    4529 bfc_allocator.cc:1105] InUse at 1331b98000 of size 3686400 next 183
# I0000 00:00:1780389715.605123    4529 bfc_allocator.cc:1105] InUse at 1331f1c000 of size 3686400 next 184
# I0000 00:00:1780389715.605125    4529 bfc_allocator.cc:1105] InUse at 13322a0000 of size 3686400 next 185
# I0000 00:00:1780389715.605128    4529 bfc_allocator.cc:1105] InUse at 1332624000 of size 3686400 next 186
# I0000 00:00:1780389715.605130    4529 bfc_allocator.cc:1105] InUse at 13329a8000 of size 3686400 next 187
# I0000 00:00:1780389715.605133    4529 bfc_allocator.cc:1105] InUse at 1332d2c000 of size 3686400 next 188
# I0000 00:00:1780389715.605135    4529 bfc_allocator.cc:1105] InUse at 13330b0000 of size 3686400 next 189
# I0000 00:00:1780389715.605138    4529 bfc_allocator.cc:1105] InUse at 1333434000 of size 3686400 next 190
# I0000 00:00:1780389715.605140    4529 bfc_allocator.cc:1105] InUse at 13337b8000 of size 3686400 next 191
# I0000 00:00:1780389715.605143    4529 bfc_allocator.cc:1105] InUse at 1333b3c000 of size 3686400 next 192
# I0000 00:00:1780389715.605145    4529 bfc_allocator.cc:1105] InUse at 1333ec0000 of size 3686400 next 193
# I0000 00:00:1780389715.605148    4529 bfc_allocator.cc:1105] InUse at 1334244000 of size 3686400 next 194
# I0000 00:00:1780389715.605150    4529 bfc_allocator.cc:1105] InUse at 13345c8000 of size 3686400 next 195
# I0000 00:00:1780389715.605153    4529 bfc_allocator.cc:1105] InUse at 133494c000 of size 3686400 next 196
# I0000 00:00:1780389715.605155    4529 bfc_allocator.cc:1105] InUse at 1334cd0000 of size 3686400 next 197
# I0000 00:00:1780389715.605158    4529 bfc_allocator.cc:1105] InUse at 1335054000 of size 3686400 next 198
# I0000 00:00:1780389715.605161    4529 bfc_allocator.cc:1105] InUse at 13353d8000 of size 3686400 next 199
# I0000 00:00:1780389715.605163    4529 bfc_allocator.cc:1105] InUse at 133575c000 of size 3686400 next 200
# I0000 00:00:1780389715.605166    4529 bfc_allocator.cc:1105] InUse at 1335ae0000 of size 3686400 next 201
# I0000 00:00:1780389715.605168    4529 bfc_allocator.cc:1105] InUse at 1335e64000 of size 3686400 next 202
# I0000 00:00:1780389715.605171    4529 bfc_allocator.cc:1105] InUse at 13361e8000 of size 3686400 next 203
# I0000 00:00:1780389715.605173    4529 bfc_allocator.cc:1105] InUse at 133656c000 of size 3686400 next 204
# I0000 00:00:1780389715.605176    4529 bfc_allocator.cc:1105] InUse at 13368f0000 of size 3686400 next 205
# I0000 00:00:1780389715.605178    4529 bfc_allocator.cc:1105] InUse at 1336c74000 of size 3686400 next 206
# I0000 00:00:1780389715.605181    4529 bfc_allocator.cc:1105] InUse at 1336ff8000 of size 3686400 next 207
# I0000 00:00:1780389715.605183    4529 bfc_allocator.cc:1105] InUse at 133737c000 of size 3686400 next 208
# I0000 00:00:1780389715.605186    4529 bfc_allocator.cc:1105] InUse at 1337700000 of size 3686400 next 209
# I0000 00:00:1780389715.605188    4529 bfc_allocator.cc:1105] InUse at 1337a84000 of size 3686400 next 210
# I0000 00:00:1780389715.605191    4529 bfc_allocator.cc:1105] InUse at 1337e08000 of size 3686400 next 211
# I0000 00:00:1780389715.605193    4529 bfc_allocator.cc:1105] InUse at 133818c000 of size 3686400 next 212
# I0000 00:00:1780389715.605196    4529 bfc_allocator.cc:1105] InUse at 1338510000 of size 3686400 next 213
# I0000 00:00:1780389715.605199    4529 bfc_allocator.cc:1105] InUse at 1338894000 of size 3686400 next 214
# I0000 00:00:1780389715.605201    4529 bfc_allocator.cc:1105] InUse at 1338c18000 of size 3686400 next 215
# I0000 00:00:1780389715.605204    4529 bfc_allocator.cc:1105] InUse at 1338f9c000 of size 3686400 next 216
# I0000 00:00:1780389715.605206    4529 bfc_allocator.cc:1105] InUse at 1339320000 of size 3686400 next 217
# I0000 00:00:1780389715.605209    4529 bfc_allocator.cc:1105] InUse at 13396a4000 of size 3686400 next 218
# I0000 00:00:1780389715.605211    4529 bfc_allocator.cc:1105] InUse at 1339a28000 of size 3686400 next 219
# I0000 00:00:1780389715.605214    4529 bfc_allocator.cc:1105] InUse at 1339dac000 of size 3686400 next 220
# I0000 00:00:1780389715.605216    4529 bfc_allocator.cc:1105] InUse at 133a130000 of size 3686400 next 221
# I0000 00:00:1780389715.605219    4529 bfc_allocator.cc:1105] InUse at 133a4b4000 of size 3686400 next 222
# I0000 00:00:1780389715.605221    4529 bfc_allocator.cc:1105] InUse at 133a838000 of size 3686400 next 223
# I0000 00:00:1780389715.605224    4529 bfc_allocator.cc:1105] InUse at 133abbc000 of size 3686400 next 224
# I0000 00:00:1780389715.605227    4529 bfc_allocator.cc:1105] InUse at 133af40000 of size 3686400 next 225
# I0000 00:00:1780389715.605229    4529 bfc_allocator.cc:1105] InUse at 133b2c4000 of size 3686400 next 226
# I0000 00:00:1780389715.605232    4529 bfc_allocator.cc:1105] InUse at 133b648000 of size 3686400 next 227
# I0000 00:00:1780389715.605234    4529 bfc_allocator.cc:1105] InUse at 133b9cc000 of size 3686400 next 228
# I0000 00:00:1780389715.605237    4529 bfc_allocator.cc:1105] InUse at 133bd50000 of size 3686400 next 229
# I0000 00:00:1780389715.605239    4529 bfc_allocator.cc:1105] InUse at 133c0d4000 of size 3686400 next 230
# I0000 00:00:1780389715.605242    4529 bfc_allocator.cc:1105] InUse at 133c458000 of size 3686400 next 231
# I0000 00:00:1780389715.605244    4529 bfc_allocator.cc:1105] InUse at 133c7dc000 of size 3686400 next 232
# I0000 00:00:1780389715.605247    4529 bfc_allocator.cc:1105] InUse at 133cb60000 of size 3686400 next 233
# I0000 00:00:1780389715.605249    4529 bfc_allocator.cc:1105] InUse at 133cee4000 of size 3686400 next 234
# I0000 00:00:1780389715.605252    4529 bfc_allocator.cc:1105] InUse at 133d268000 of size 3686400 next 235
# I0000 00:00:1780389715.605254    4529 bfc_allocator.cc:1105] InUse at 133d5ec000 of size 3686400 next 236
# I0000 00:00:1780389715.605257    4529 bfc_allocator.cc:1105] InUse at 133d970000 of size 3686400 next 237
# I0000 00:00:1780389715.605259    4529 bfc_allocator.cc:1105] InUse at 133dcf4000 of size 3686400 next 238
# I0000 00:00:1780389715.605262    4529 bfc_allocator.cc:1105] InUse at 133e078000 of size 3686400 next 239
# I0000 00:00:1780389715.605265    4529 bfc_allocator.cc:1105] InUse at 133e3fc000 of size 3686400 next 240
# I0000 00:00:1780389715.605268    4529 bfc_allocator.cc:1105] InUse at 133e780000 of size 3686400 next 241
# I0000 00:00:1780389715.605270    4529 bfc_allocator.cc:1105] InUse at 133eb04000 of size 3686400 next 242
# I0000 00:00:1780389715.605273    4529 bfc_allocator.cc:1105] InUse at 133ee88000 of size 3686400 next 243
# I0000 00:00:1780389715.605275    4529 bfc_allocator.cc:1105] InUse at 133f20c000 of size 3686400 next 244
# I0000 00:00:1780389715.605278    4529 bfc_allocator.cc:1105] InUse at 133f590000 of size 3686400 next 245
# I0000 00:00:1780389715.605280    4529 bfc_allocator.cc:1105] InUse at 133f914000 of size 3686400 next 246
# I0000 00:00:1780389715.605283    4529 bfc_allocator.cc:1105] InUse at 133fc98000 of size 3686400 next 247
# I0000 00:00:1780389715.605285    4529 bfc_allocator.cc:1105] InUse at 134001c000 of size 3686400 next 248
# I0000 00:00:1780389715.605288    4529 bfc_allocator.cc:1105] InUse at 13403a0000 of size 3686400 next 249
# I0000 00:00:1780389715.605290    4529 bfc_allocator.cc:1105] InUse at 1340724000 of size 3686400 next 250
# I0000 00:00:1780389715.605293    4529 bfc_allocator.cc:1105] InUse at 1340aa8000 of size 3686400 next 251
# I0000 00:00:1780389715.605295    4529 bfc_allocator.cc:1105] InUse at 1340e2c000 of size 3686400 next 252
# I0000 00:00:1780389715.605298    4529 bfc_allocator.cc:1105] InUse at 13411b0000 of size 3686400 next 253
# I0000 00:00:1780389715.605300    4529 bfc_allocator.cc:1105] InUse at 1341534000 of size 3686400 next 254
# I0000 00:00:1780389715.605303    4529 bfc_allocator.cc:1105] InUse at 13418b8000 of size 3686400 next 255
# I0000 00:00:1780389715.605305    4529 bfc_allocator.cc:1105] InUse at 1341c3c000 of size 3686400 next 256
# I0000 00:00:1780389715.605308    4529 bfc_allocator.cc:1105] InUse at 1341fc0000 of size 3686400 next 257
# I0000 00:00:1780389715.605310    4529 bfc_allocator.cc:1105] InUse at 1342344000 of size 3686400 next 258
# I0000 00:00:1780389715.605313    4529 bfc_allocator.cc:1105] InUse at 13426c8000 of size 3686400 next 259
# I0000 00:00:1780389715.605315    4529 bfc_allocator.cc:1105] InUse at 1342a4c000 of size 3686400 next 260
# I0000 00:00:1780389715.605318    4529 bfc_allocator.cc:1105] InUse at 1342dd0000 of size 3686400 next 261
# I0000 00:00:1780389715.605320    4529 bfc_allocator.cc:1105] InUse at 1343154000 of size 3686400 next 262
# I0000 00:00:1780389715.605323    4529 bfc_allocator.cc:1105] InUse at 13434d8000 of size 3686400 next 263
# I0000 00:00:1780389715.605325    4529 bfc_allocator.cc:1105] InUse at 134385c000 of size 3686400 next 264
# I0000 00:00:1780389715.605328    4529 bfc_allocator.cc:1105] InUse at 1343be0000 of size 3686400 next 265
# I0000 00:00:1780389715.605330    4529 bfc_allocator.cc:1105] InUse at 1343f64000 of size 3686400 next 266
# I0000 00:00:1780389715.605333    4529 bfc_allocator.cc:1105] InUse at 13442e8000 of size 3686400 next 267
# I0000 00:00:1780389715.605336    4529 bfc_allocator.cc:1105] InUse at 134466c000 of size 3686400 next 268
# I0000 00:00:1780389715.605338    4529 bfc_allocator.cc:1105] InUse at 13449f0000 of size 3686400 next 269
# I0000 00:00:1780389715.605341    4529 bfc_allocator.cc:1105] InUse at 1344d74000 of size 3686400 next 270
# I0000 00:00:1780389715.605343    4529 bfc_allocator.cc:1105] InUse at 13450f8000 of size 3686400 next 271
# I0000 00:00:1780389715.605346    4529 bfc_allocator.cc:1105] InUse at 134547c000 of size 3686400 next 272
# I0000 00:00:1780389715.605348    4529 bfc_allocator.cc:1105] InUse at 1345800000 of size 3686400 next 273
# I0000 00:00:1780389715.605351    4529 bfc_allocator.cc:1105] InUse at 1345b84000 of size 3686400 next 274
# I0000 00:00:1780389715.605353    4529 bfc_allocator.cc:1105] InUse at 1345f08000 of size 3686400 next 275
# I0000 00:00:1780389715.605356    4529 bfc_allocator.cc:1105] InUse at 134628c000 of size 3686400 next 276
# I0000 00:00:1780389715.605358    4529 bfc_allocator.cc:1105] InUse at 1346610000 of size 3686400 next 277
# I0000 00:00:1780389715.605361    4529 bfc_allocator.cc:1105] InUse at 1346994000 of size 3686400 next 278
# I0000 00:00:1780389715.605363    4529 bfc_allocator.cc:1105] InUse at 1346d18000 of size 3686400 next 279
# I0000 00:00:1780389715.605366    4529 bfc_allocator.cc:1105] InUse at 134709c000 of size 3686400 next 280
# I0000 00:00:1780389715.605368    4529 bfc_allocator.cc:1105] InUse at 1347420000 of size 3686400 next 281
# I0000 00:00:1780389715.605371    4529 bfc_allocator.cc:1105] InUse at 13477a4000 of size 3686400 next 282
# I0000 00:00:1780389715.605373    4529 bfc_allocator.cc:1105] InUse at 1347b28000 of size 3686400 next 283
# I0000 00:00:1780389715.605376    4529 bfc_allocator.cc:1105] InUse at 1347eac000 of size 3686400 next 284
# I0000 00:00:1780389715.605378    4529 bfc_allocator.cc:1105] InUse at 1348230000 of size 3686400 next 285
# I0000 00:00:1780389715.605381    4529 bfc_allocator.cc:1105] InUse at 13485b4000 of size 3686400 next 286
# I0000 00:00:1780389715.605383    4529 bfc_allocator.cc:1105] InUse at 1348938000 of size 3686400 next 287
# I0000 00:00:1780389715.605386    4529 bfc_allocator.cc:1105] InUse at 1348cbc000 of size 3686400 next 288
# I0000 00:00:1780389715.605389    4529 bfc_allocator.cc:1105] InUse at 1349040000 of size 6029312 next 18446744073709551615
# I0000 00:00:1780389715.605392    4529 bfc_allocator.cc:1085] Next region of size 1073741824
# I0000 00:00:1780389715.605395    4529 bfc_allocator.cc:1105] InUse at 1349600000 of size 3686400 next 290
# I0000 00:00:1780389715.605397    4529 bfc_allocator.cc:1105] InUse at 1349984000 of size 3686400 next 291
# I0000 00:00:1780389715.605400    4529 bfc_allocator.cc:1105] InUse at 1349d08000 of size 3686400 next 292
# I0000 00:00:1780389715.605402    4529 bfc_allocator.cc:1105] InUse at 134a08c000 of size 3686400 next 293
# I0000 00:00:1780389715.605405    4529 bfc_allocator.cc:1105] InUse at 134a410000 of size 3686400 next 294
# I0000 00:00:1780389715.605407    4529 bfc_allocator.cc:1105] InUse at 134a794000 of size 3686400 next 295
# I0000 00:00:1780389715.605410    4529 bfc_allocator.cc:1105] InUse at 134ab18000 of size 3686400 next 296
# I0000 00:00:1780389715.605413    4529 bfc_allocator.cc:1105] InUse at 134ae9c000 of size 3686400 next 297
# I0000 00:00:1780389715.605415    4529 bfc_allocator.cc:1105] InUse at 134b220000 of size 3686400 next 298
# I0000 00:00:1780389715.605418    4529 bfc_allocator.cc:1105] InUse at 134b5a4000 of size 3686400 next 299
# I0000 00:00:1780389715.605420    4529 bfc_allocator.cc:1105] InUse at 134b928000 of size 3686400 next 300
# I0000 00:00:1780389715.605423    4529 bfc_allocator.cc:1105] InUse at 134bcac000 of size 3686400 next 301
# I0000 00:00:1780389715.605425    4529 bfc_allocator.cc:1105] InUse at 134c030000 of size 3686400 next 302
# I0000 00:00:1780389715.605428    4529 bfc_allocator.cc:1105] InUse at 134c3b4000 of size 3686400 next 303
# I0000 00:00:1780389715.605430    4529 bfc_allocator.cc:1105] InUse at 134c738000 of size 3686400 next 304
# I0000 00:00:1780389715.605433    4529 bfc_allocator.cc:1105] InUse at 134cabc000 of size 3686400 next 305
# I0000 00:00:1780389715.605436    4529 bfc_allocator.cc:1105] InUse at 134ce40000 of size 3686400 next 306
# I0000 00:00:1780389715.605438    4529 bfc_allocator.cc:1105] InUse at 134d1c4000 of size 3686400 next 307
# I0000 00:00:1780389715.605441    4529 bfc_allocator.cc:1105] InUse at 134d548000 of size 3686400 next 308
# I0000 00:00:1780389715.605443    4529 bfc_allocator.cc:1105] InUse at 134d8cc000 of size 3686400 next 309
# I0000 00:00:1780389715.605446    4529 bfc_allocator.cc:1105] InUse at 134dc50000 of size 3686400 next 310
# I0000 00:00:1780389715.605448    4529 bfc_allocator.cc:1105] InUse at 134dfd4000 of size 3686400 next 311
# I0000 00:00:1780389715.605451    4529 bfc_allocator.cc:1105] InUse at 134e358000 of size 3686400 next 312
# I0000 00:00:1780389715.605453    4529 bfc_allocator.cc:1105] InUse at 134e6dc000 of size 3686400 next 313
# I0000 00:00:1780389715.605456    4529 bfc_allocator.cc:1105] InUse at 134ea60000 of size 3686400 next 314
# I0000 00:00:1780389715.605459    4529 bfc_allocator.cc:1105] InUse at 134ede4000 of size 3686400 next 315
# I0000 00:00:1780389715.605461    4529 bfc_allocator.cc:1105] InUse at 134f168000 of size 3686400 next 316
# I0000 00:00:1780389715.605464    4529 bfc_allocator.cc:1105] InUse at 134f4ec000 of size 3686400 next 317
# I0000 00:00:1780389715.605466    4529 bfc_allocator.cc:1105] InUse at 134f870000 of size 3686400 next 318
# I0000 00:00:1780389715.605469    4529 bfc_allocator.cc:1105] InUse at 134fbf4000 of size 3686400 next 319
# I0000 00:00:1780389715.605471    4529 bfc_allocator.cc:1105] InUse at 134ff78000 of size 3686400 next 320
# I0000 00:00:1780389715.605474    4529 bfc_allocator.cc:1105] InUse at 13502fc000 of size 3686400 next 321
# I0000 00:00:1780389715.605476    4529 bfc_allocator.cc:1105] InUse at 1350680000 of size 3686400 next 322
# I0000 00:00:1780389715.605479    4529 bfc_allocator.cc:1105] InUse at 1350a04000 of size 3686400 next 323
# I0000 00:00:1780389715.605481    4529 bfc_allocator.cc:1105] InUse at 1350d88000 of size 3686400 next 324
# I0000 00:00:1780389715.605484    4529 bfc_allocator.cc:1105] InUse at 135110c000 of size 3686400 next 325
# I0000 00:00:1780389715.605486    4529 bfc_allocator.cc:1105] InUse at 1351490000 of size 3686400 next 326
# I0000 00:00:1780389715.605489    4529 bfc_allocator.cc:1105] InUse at 1351814000 of size 3686400 next 327
# I0000 00:00:1780389715.605492    4529 bfc_allocator.cc:1105] InUse at 1351b98000 of size 3686400 next 328
# I0000 00:00:1780389715.605494    4529 bfc_allocator.cc:1105] InUse at 1351f1c000 of size 3686400 next 329
# I0000 00:00:1780389715.605497    4529 bfc_allocator.cc:1105] InUse at 13522a0000 of size 3686400 next 330
# I0000 00:00:1780389715.605499    4529 bfc_allocator.cc:1105] InUse at 1352624000 of size 3686400 next 331
# I0000 00:00:1780389715.605502    4529 bfc_allocator.cc:1105] InUse at 13529a8000 of size 3686400 next 332
# I0000 00:00:1780389715.605504    4529 bfc_allocator.cc:1105] InUse at 1352d2c000 of size 3686400 next 333
# I0000 00:00:1780389715.605507    4529 bfc_allocator.cc:1105] InUse at 13530b0000 of size 3686400 next 334
# I0000 00:00:1780389715.605509    4529 bfc_allocator.cc:1105] InUse at 1353434000 of size 3686400 next 335
# I0000 00:00:1780389715.605512    4529 bfc_allocator.cc:1105] InUse at 13537b8000 of size 3686400 next 336
# I0000 00:00:1780389715.605514    4529 bfc_allocator.cc:1105] InUse at 1353b3c000 of size 3686400 next 337
# I0000 00:00:1780389715.605517    4529 bfc_allocator.cc:1105] InUse at 1353ec0000 of size 3686400 next 338
# I0000 00:00:1780389715.605519    4529 bfc_allocator.cc:1105] InUse at 1354244000 of size 3686400 next 339
# I0000 00:00:1780389715.605522    4529 bfc_allocator.cc:1105] InUse at 13545c8000 of size 3686400 next 340
# I0000 00:00:1780389715.605524    4529 bfc_allocator.cc:1105] InUse at 135494c000 of size 3686400 next 341
# I0000 00:00:1780389715.605527    4529 bfc_allocator.cc:1105] InUse at 1354cd0000 of size 3686400 next 342
# I0000 00:00:1780389715.605529    4529 bfc_allocator.cc:1105] InUse at 1355054000 of size 3686400 next 343
# I0000 00:00:1780389715.605532    4529 bfc_allocator.cc:1105] InUse at 13553d8000 of size 3686400 next 344
# I0000 00:00:1780389715.605534    4529 bfc_allocator.cc:1105] InUse at 135575c000 of size 3686400 next 345
# I0000 00:00:1780389715.605537    4529 bfc_allocator.cc:1105] InUse at 1355ae0000 of size 3686400 next 346
# I0000 00:00:1780389715.605539    4529 bfc_allocator.cc:1105] InUse at 1355e64000 of size 3686400 next 347
# I0000 00:00:1780389715.605542    4529 bfc_allocator.cc:1105] InUse at 13561e8000 of size 3686400 next 348
# I0000 00:00:1780389715.605544    4529 bfc_allocator.cc:1105] InUse at 135656c000 of size 3686400 next 349
# I0000 00:00:1780389715.605548    4529 bfc_allocator.cc:1105] InUse at 13568f0000 of size 3686400 next 350
# I0000 00:00:1780389715.605551    4529 bfc_allocator.cc:1105] InUse at 1356c74000 of size 3686400 next 351
# I0000 00:00:1780389715.605553    4529 bfc_allocator.cc:1105] InUse at 1356ff8000 of size 3686400 next 352
# I0000 00:00:1780389715.605556    4529 bfc_allocator.cc:1105] InUse at 135737c000 of size 3686400 next 353
# I0000 00:00:1780389715.605558    4529 bfc_allocator.cc:1105] InUse at 1357700000 of size 3686400 next 354
# I0000 00:00:1780389715.605561    4529 bfc_allocator.cc:1105] InUse at 1357a84000 of size 3686400 next 355
# I0000 00:00:1780389715.605563    4529 bfc_allocator.cc:1105] InUse at 1357e08000 of size 3686400 next 356
# I0000 00:00:1780389715.605566    4529 bfc_allocator.cc:1105] InUse at 135818c000 of size 3686400 next 357
# I0000 00:00:1780389715.605568    4529 bfc_allocator.cc:1105] InUse at 1358510000 of size 3686400 next 358
# I0000 00:00:1780389715.605571    4529 bfc_allocator.cc:1105] InUse at 1358894000 of size 3686400 next 359
# I0000 00:00:1780389715.605573    4529 bfc_allocator.cc:1105] InUse at 1358c18000 of size 3686400 next 360
# I0000 00:00:1780389715.605576    4529 bfc_allocator.cc:1105] InUse at 1358f9c000 of size 3686400 next 361
# I0000 00:00:1780389715.605578    4529 bfc_allocator.cc:1105] InUse at 1359320000 of size 3686400 next 362
# I0000 00:00:1780389715.605581    4529 bfc_allocator.cc:1105] InUse at 13596a4000 of size 3686400 next 363
# I0000 00:00:1780389715.605584    4529 bfc_allocator.cc:1105] InUse at 1359a28000 of size 3686400 next 364
# I0000 00:00:1780389715.605586    4529 bfc_allocator.cc:1105] InUse at 1359dac000 of size 3686400 next 365
# I0000 00:00:1780389715.605589    4529 bfc_allocator.cc:1105] InUse at 135a130000 of size 3686400 next 366
# I0000 00:00:1780389715.605591    4529 bfc_allocator.cc:1105] InUse at 135a4b4000 of size 3686400 next 367
# I0000 00:00:1780389715.605594    4529 bfc_allocator.cc:1105] InUse at 135a838000 of size 3686400 next 368
# I0000 00:00:1780389715.605596    4529 bfc_allocator.cc:1105] InUse at 135abbc000 of size 3686400 next 369
# I0000 00:00:1780389715.605599    4529 bfc_allocator.cc:1105] InUse at 135af40000 of size 3686400 next 370
# I0000 00:00:1780389715.605601    4529 bfc_allocator.cc:1105] InUse at 135b2c4000 of size 3686400 next 371
# I0000 00:00:1780389715.605604    4529 bfc_allocator.cc:1105] InUse at 135b648000 of size 3686400 next 372
# I0000 00:00:1780389715.605606    4529 bfc_allocator.cc:1105] InUse at 135b9cc000 of size 3686400 next 373
# I0000 00:00:1780389715.605609    4529 bfc_allocator.cc:1105] InUse at 135bd50000 of size 3686400 next 374
# I0000 00:00:1780389715.605611    4529 bfc_allocator.cc:1105] InUse at 135c0d4000 of size 3686400 next 375
# I0000 00:00:1780389715.605614    4529 bfc_allocator.cc:1105] InUse at 135c458000 of size 3686400 next 376
# I0000 00:00:1780389715.605616    4529 bfc_allocator.cc:1105] InUse at 135c7dc000 of size 3686400 next 377
# I0000 00:00:1780389715.605619    4529 bfc_allocator.cc:1105] InUse at 135cb60000 of size 3686400 next 378
# I0000 00:00:1780389715.605621    4529 bfc_allocator.cc:1105] InUse at 135cee4000 of size 3686400 next 379
# I0000 00:00:1780389715.605624    4529 bfc_allocator.cc:1105] InUse at 135d268000 of size 3686400 next 380
# I0000 00:00:1780389715.605626    4529 bfc_allocator.cc:1105] InUse at 135d5ec000 of size 3686400 next 381
# I0000 00:00:1780389715.605629    4529 bfc_allocator.cc:1105] InUse at 135d970000 of size 3686400 next 382
# I0000 00:00:1780389715.605631    4529 bfc_allocator.cc:1105] InUse at 135dcf4000 of size 3686400 next 383
# I0000 00:00:1780389715.605634    4529 bfc_allocator.cc:1105] InUse at 135e078000 of size 3686400 next 384
# I0000 00:00:1780389715.605637    4529 bfc_allocator.cc:1105] InUse at 135e3fc000 of size 3686400 next 385
# I0000 00:00:1780389715.605639    4529 bfc_allocator.cc:1105] InUse at 135e780000 of size 3686400 next 386
# I0000 00:00:1780389715.605642    4529 bfc_allocator.cc:1105] InUse at 135eb04000 of size 3686400 next 387
# I0000 00:00:1780389715.605644    4529 bfc_allocator.cc:1105] InUse at 135ee88000 of size 3686400 next 388
# I0000 00:00:1780389715.605647    4529 bfc_allocator.cc:1105] InUse at 135f20c000 of size 3686400 next 389
# I0000 00:00:1780389715.605649    4529 bfc_allocator.cc:1105] InUse at 135f590000 of size 3686400 next 390
# I0000 00:00:1780389715.605652    4529 bfc_allocator.cc:1105] InUse at 135f914000 of size 3686400 next 391
# I0000 00:00:1780389715.605654    4529 bfc_allocator.cc:1105] InUse at 135fc98000 of size 3686400 next 392
# I0000 00:00:1780389715.605657    4529 bfc_allocator.cc:1105] InUse at 136001c000 of size 3686400 next 393
# I0000 00:00:1780389715.605659    4529 bfc_allocator.cc:1105] InUse at 13603a0000 of size 3686400 next 394
# I0000 00:00:1780389715.605661    4529 bfc_allocator.cc:1105] InUse at 1360724000 of size 3686400 next 395
# I0000 00:00:1780389715.605664    4529 bfc_allocator.cc:1105] InUse at 1360aa8000 of size 3686400 next 396
# I0000 00:00:1780389715.605666    4529 bfc_allocator.cc:1105] InUse at 1360e2c000 of size 3686400 next 397
# ...
# I0000 00:00:1780389715.606696    4529 bfc_allocator.cc:1105] InUse at 13a1534000 of size 3686400 next 690
# I0000 00:00:1780389715.606698    4529 bfc_allocator.cc:1105] InUse at 13a18b8000 of size 3686400 next 691
# I0000 00:00:1780389715.606701    4529 bfc_allocator.cc:1105] InUse at 13a1c3c000 of size 3686400 next 692
# I0000 00:00:1780389715.606703    4529 bfc_allocator.cc:1105] InUse at 13a1fc0000 of size 3686400 next 693
# I0000 00:00:1780389715.606706    4529 bfc_allocator.cc:1105] InUse at 13a2344000 of size 3686400 next 694
# I0000 00:00:1780389715.606708    4529 bfc_allocator.cc:1105] InUse at 13a26c8000 of size 3686400 next 695
# I0000 00:00:1780389715.606711    4529 bfc_allocator.cc:1105] InUse at 13a2a4c000 of size 3686400 next 696
# I0000 00:00:1780389715.606713    4529 bfc_allocator.cc:1105] InUse at 13a2dd0000 of size 3686400 next 697
# I0000 00:00:1780389715.606716    4529 bfc_allocator.cc:1105] InUse at 13a3154000 of size 3686400 next 698
# I0000 00:00:1780389715.606718    4529 bfc_allocator.cc:1105] InUse at 13a34d8000 of size 3686400 next 699
# I0000 00:00:1780389715.606721    4529 bfc_allocator.cc:1105] InUse at 13a385c000 of size 3686400 next 700
# I0000 00:00:1780389715.606762    4529 bfc_allocator.cc:1105] InUse at 13a3be0000 of size 3686400 next 701
# I0000 00:00:1780389715.606767    4529 bfc_allocator.cc:1105] InUse at 13a3f64000 of size 3686400 next 702
# I0000 00:00:1780389715.606769    4529 bfc_allocator.cc:1105] InUse at 13a42e8000 of size 3686400 next 703
# I0000 00:00:1780389715.606772    4529 bfc_allocator.cc:1105] InUse at 13a466c000 of size 3686400 next 704
# I0000 00:00:1780389715.606774    4529 bfc_allocator.cc:1105] InUse at 13a49f0000 of size 3686400 next 705
# I0000 00:00:1780389715.606777    4529 bfc_allocator.cc:1105] InUse at 13a4d74000 of size 3686400 next 706
# I0000 00:00:1780389715.606779    4529 bfc_allocator.cc:1105] InUse at 13a50f8000 of size 3686400 next 707
# I0000 00:00:1780389715.606782    4529 bfc_allocator.cc:1105] InUse at 13a547c000 of size 3686400 next 708
# I0000 00:00:1780389715.606784    4529 bfc_allocator.cc:1105] InUse at 13a5800000 of size 3686400 next 709
# I0000 00:00:1780389715.606787    4529 bfc_allocator.cc:1105] InUse at 13a5b84000 of size 3686400 next 710
# I0000 00:00:1780389715.606790    4529 bfc_allocator.cc:1105] InUse at 13a5f08000 of size 3686400 next 711
# I0000 00:00:1780389715.606792    4529 bfc_allocator.cc:1105] InUse at 13a628c000 of size 3686400 next 712
# I0000 00:00:1780389715.606795    4529 bfc_allocator.cc:1105] InUse at 13a6610000 of size 3686400 next 713
# I0000 00:00:1780389715.606797    4529 bfc_allocator.cc:1105] InUse at 13a6994000 of size 3686400 next 714
# I0000 00:00:1780389715.606800    4529 bfc_allocator.cc:1105] InUse at 13a6d18000 of size 3686400 next 715
# I0000 00:00:1780389715.606805    4529 bfc_allocator.cc:1105] InUse at 13a709c000 of size 3686400 next 716
# I0000 00:00:1780389715.606807    4529 bfc_allocator.cc:1105] InUse at 13a7420000 of size 3686400 next 717
# I0000 00:00:1780389715.606810    4529 bfc_allocator.cc:1105] InUse at 13a77a4000 of size 3686400 next 718
# I0000 00:00:1780389715.606812    4529 bfc_allocator.cc:1105] InUse at 13a7b28000 of size 3686400 next 719
# I0000 00:00:1780389715.606815    4529 bfc_allocator.cc:1105] InUse at 13a7eac000 of size 3686400 next 720
# I0000 00:00:1780389715.606817    4529 bfc_allocator.cc:1105] InUse at 13a8230000 of size 3686400 next 721
# I0000 00:00:1780389715.606820    4529 bfc_allocator.cc:1105] InUse at 13a85b4000 of size 3686400 next 722
# I0000 00:00:1780389715.606822    4529 bfc_allocator.cc:1105] InUse at 13a8938000 of size 3686400 next 723
# I0000 00:00:1780389715.606825    4529 bfc_allocator.cc:1105] InUse at 13a8cbc000 of size 3686400 next 724
# I0000 00:00:1780389715.606827    4529 bfc_allocator.cc:1105] InUse at 13a9040000 of size 3686400 next 725
# I0000 00:00:1780389715.606830    4529 bfc_allocator.cc:1105] InUse at 13a93c4000 of size 3686400 next 726
# I0000 00:00:1780389715.606833    4529 bfc_allocator.cc:1105] InUse at 13a9748000 of size 3686400 next 727
# I0000 00:00:1780389715.606835    4529 bfc_allocator.cc:1105] InUse at 13a9acc000 of size 3686400 next 728
# I0000 00:00:1780389715.606837    4529 bfc_allocator.cc:1105] InUse at 13a9e50000 of size 3686400 next 729
# I0000 00:00:1780389715.606840    4529 bfc_allocator.cc:1105] InUse at 13aa1d4000 of size 3686400 next 730
# I0000 00:00:1780389715.606843    4529 bfc_allocator.cc:1105] InUse at 13aa558000 of size 3686400 next 731
# I0000 00:00:1780389715.606845    4529 bfc_allocator.cc:1105] InUse at 13aa8dc000 of size 3686400 next 732
# I0000 00:00:1780389715.606848    4529 bfc_allocator.cc:1105] InUse at 13aac60000 of size 3686400 next 733
# I0000 00:00:1780389715.606850    4529 bfc_allocator.cc:1105] InUse at 13aafe4000 of size 3686400 next 734
# I0000 00:00:1780389715.606853    4529 bfc_allocator.cc:1105] InUse at 13ab368000 of size 3686400 next 735
# I0000 00:00:1780389715.606855    4529 bfc_allocator.cc:1105] InUse at 13ab6ec000 of size 3686400 next 736
# I0000 00:00:1780389715.606859    4529 bfc_allocator.cc:1105] InUse at 13aba70000 of size 1223884800 next 737
# I0000 00:00:1780389715.606862    4529 bfc_allocator.cc:1105] InUse at 13f49a0000 of size 256 next 738
# I0000 00:00:1780389715.606865    4529 bfc_allocator.cc:1105] InUse at 13f49a0100 of size 256 next 739
# I0000 00:00:1780389715.606867    4529 bfc_allocator.cc:1105] InUse at 13f49a0200 of size 256 next 740
# I0000 00:00:1780389715.606870    4529 bfc_allocator.cc:1105] InUse at 13f49a0300 of size 256 next 741
# I0000 00:00:1780389715.606873    4529 bfc_allocator.cc:1105] InUse at 13f49a0400 of size 348519424 next 18446744073709551615
# I0000 00:00:1780389715.606876    4529 bfc_allocator.cc:1085] Next region of size 4294967296
# I0000 00:00:1780389715.606880    4529 bfc_allocator.cc:1105] InUse at 1409600000 of size 10224128 next 743
# I0000 00:00:1780389715.606883    4529 bfc_allocator.cc:1105] InUse at 1409fc0200 of size 2044928 next 744
# I0000 00:00:1780389715.606886    4529 bfc_allocator.cc:1105] InUse at 140a1b3600 of size 256 next 745
# I0000 00:00:1780389715.606888    4529 bfc_allocator.cc:1105] InUse at 140a1b3700 of size 256 next 746
# I0000 00:00:1780389715.606891    4529 bfc_allocator.cc:1105] InUse at 140a1b3800 of size 256 next 747
# I0000 00:00:1780389715.606894    4529 bfc_allocator.cc:1105] InUse at 140a1b3900 of size 256 next 748
# I0000 00:00:1780389715.606897    4529 bfc_allocator.cc:1105] InUse at 140a1b3a00 of size 256 next 749
# I0000 00:00:1780389715.606899    4529 bfc_allocator.cc:1105] InUse at 140a1b3b00 of size 256 next 750
# I0000 00:00:1780389715.606902    4529 bfc_allocator.cc:1105] InUse at 140a1b3c00 of size 256 next 751
# I0000 00:00:1780389715.606904    4529 bfc_allocator.cc:1105] InUse at 140a1b3d00 of size 256 next 753
# I0000 00:00:1780389715.606907    4529 bfc_allocator.cc:1105] InUse at 140a1b3e00 of size 256 next 754
# I0000 00:00:1780389715.606910    4529 bfc_allocator.cc:1105] InUse at 140a1b3f00 of size 256 next 752
# I0000 00:00:1780389715.606912    4529 bfc_allocator.cc:1105] InUse at 140a1b4000 of size 256 next 755
# I0000 00:00:1780389715.606915    4529 bfc_allocator.cc:1105] InUse at 140a1b4100 of size 256 next 760
# I0000 00:00:1780389715.606917    4529 bfc_allocator.cc:1105] InUse at 140a1b4200 of size 256 next 758
# I0000 00:00:1780389715.606920    4529 bfc_allocator.cc:1105] InUse at 140a1b4300 of size 256 next 759
# I0000 00:00:1780389715.606922    4529 bfc_allocator.cc:1105] InUse at 140a1b4400 of size 256 next 763
# I0000 00:00:1780389715.606925    4529 bfc_allocator.cc:1105] InUse at 140a1b4500 of size 256 next 756
# I0000 00:00:1780389715.606928    4529 bfc_allocator.cc:1105] InUse at 140a1b4600 of size 768 next 757
# I0000 00:00:1780389715.606931    4529 bfc_allocator.cc:1105] InUse at 140a1b4900 of size 256 next 765
# I0000 00:00:1780389715.606933    4529 bfc_allocator.cc:1105] InUse at 140a1b4a00 of size 256 next 764
# I0000 00:00:1780389715.606936    4529 bfc_allocator.cc:1105] InUse at 140a1b4b00 of size 256 next 768
# I0000 00:00:1780389715.606939    4529 bfc_allocator.cc:1105] InUse at 140a1b4c00 of size 256 next 770
# I0000 00:00:1780389715.606941    4529 bfc_allocator.cc:1105] InUse at 140a1b4d00 of size 256 next 771
# I0000 00:00:1780389715.606944    4529 bfc_allocator.cc:1105] Free  at 140a1b4e00 of size 2816 next 773
# I0000 00:00:1780389715.606947    4529 bfc_allocator.cc:1105] InUse at 140a1b5900 of size 1280 next 774
# I0000 00:00:1780389715.606949    4529 bfc_allocator.cc:1105] Free  at 140a1b5e00 of size 3840 next 762
# I0000 00:00:1780389715.606952    4529 bfc_allocator.cc:1105] InUse at 140a1b6d00 of size 4608 next 761
# I0000 00:00:1780389715.606954    4529 bfc_allocator.cc:1105] Free  at 140a1b7f00 of size 117964800 next 767
# I0000 00:00:1780389715.606957    4529 bfc_allocator.cc:1105] InUse at 1411237f00 of size 58982400 next 766
# I0000 00:00:1780389715.606960    4529 bfc_allocator.cc:1105] InUse at 1414a77f00 of size 2447769600 next 772
# I0000 00:00:1780389715.606962    4529 bfc_allocator.cc:1105] InUse at 14a68d7f00 of size 1223884800 next 775
# I0000 00:00:1780389715.606965    4529 bfc_allocator.cc:1105] Free  at 14ef807f00 of size 434077952 next 18446744073709551615
# I0000 00:00:1780389715.606967    4529 bfc_allocator.cc:1110]      Summary of in-use Chunks by size:
# I0000 00:00:1780389715.606970    4529 bfc_allocator.cc:1113] 25 Chunks of size 256 totalling 6.2KiB
# I0000 00:00:1780389715.606976    4529 bfc_allocator.cc:1113] 1 Chunks of size 768 totalling 768B
# I0000 00:00:1780389715.606979    4529 bfc_allocator.cc:1113] 2 Chunks of size 1280 totalling 2.5KiB
# I0000 00:00:1780389715.606983    4529 bfc_allocator.cc:1113] 1 Chunks of size 4608 totalling 4.5KiB
# I0000 00:00:1780389715.606986    4529 bfc_allocator.cc:1113] 1 Chunks of size 2044928 totalling 1.95MiB
# I0000 00:00:1780389715.606989    4529 bfc_allocator.cc:1113] 725 Chunks of size 3686400 totalling 2.49GiB
# I0000 00:00:1780389715.606992    4529 bfc_allocator.cc:1113] 1 Chunks of size 4063232 totalling 3.88MiB
# I0000 00:00:1780389715.606996    4529 bfc_allocator.cc:1113] 1 Chunks of size 4193024 totalling 4.00MiB
# I0000 00:00:1780389715.606999    4529 bfc_allocator.cc:1113] 1 Chunks of size 4194304 totalling 4.00MiB
# I0000 00:00:1780389715.607002    4529 bfc_allocator.cc:1113] 1 Chunks of size 4440064 totalling 4.23MiB
# I0000 00:00:1780389715.607005    4529 bfc_allocator.cc:1113] 1 Chunks of size 4685824 totalling 4.47MiB
# I0000 00:00:1780389715.607009    4529 bfc_allocator.cc:1113] 1 Chunks of size 4702208 totalling 4.48MiB
# I0000 00:00:1780389715.607012    4529 bfc_allocator.cc:1113] 1 Chunks of size 5193728 totalling 4.95MiB
# I0000 00:00:1780389715.607015    4529 bfc_allocator.cc:1113] 1 Chunks of size 5718016 totalling 5.45MiB
# I0000 00:00:1780389715.607018    4529 bfc_allocator.cc:1113] 1 Chunks of size 6029312 totalling 5.75MiB
# I0000 00:00:1780389715.607021    4529 bfc_allocator.cc:1113] 1 Chunks of size 6701056 totalling 6.39MiB
# I0000 00:00:1780389715.607024    4529 bfc_allocator.cc:1113] 1 Chunks of size 10224128 totalling 9.75MiB
# I0000 00:00:1780389715.607028    4529 bfc_allocator.cc:1113] 1 Chunks of size 58982400 totalling 56.25MiB
# I0000 00:00:1780389715.607031    4529 bfc_allocator.cc:1113] 1 Chunks of size 348519424 totalling 332.37MiB
# I0000 00:00:1780389715.607034    4529 bfc_allocator.cc:1113] 2 Chunks of size 1223884800 totalling 2.28GiB
# I0000 00:00:1780389715.607037    4529 bfc_allocator.cc:1113] 1 Chunks of size 2447769600 totalling 2.28GiB
# I0000 00:00:1780389715.607041    4529 bfc_allocator.cc:1117] Sum Total of in-use chunks: 7.49GiB
# I0000 00:00:1780389715.607044    4529 bfc_allocator.cc:1119] Total size in pool: 8.00GiB memory_limit_: 8.84GiB available size: 863.00MiB curr_region_allocation_bytes_: 8.00GiB
# I0000 00:00:1780389715.607048    4529 bfc_allocator.cc:1128] Stats:
# Limit:                         8.84GiB
# InUse:                         7.49GiB
# MaxInUse:                      7.49GiB
# NumAllocs:                         812
# MaxAllocSize:                  2.28GiB
# Reserved:                           0B
# PeakReserved:                       0B
# LargestFreeBlock:                   0B
#
# W0000 00:00:1780389715.607056    4529 bfc_allocator.cc:513] *************************************************x*********************************************_____
# W0000 00:00:1780389715.607080    4529 op_kernel.cc:1845] RESOURCE_EXHAUSTED: failed to allocate memory
# W0000 00:00:1780389715.607101    4529 local_rendezvous.cc:412] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: failed to allocate memory
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 X_unlab_aug = scale_noise(combined_X_unlab)
#       2 print(X_unlab_aug.shape)
#       3
#       4 X_ulb_scale_tensor = tf.convert_to_tensor(X_unlab_aug)
#
# Cell In[11], line 5, in scale_noise(X)
#       2 def scale_noise(X):
#       3     mu, sigma = 1.0, 0.01
#       4     noise = tf.random.normal(shape=tf.shape(X), mean=mu, stddev=sigma, dtype= tf.float32)
# ----> 5     X = tf.cast(X, dtype=tf.float32) * noise
#       6     # noise = np.random.normal(mu,sigma,X.shape)
#       7     # X = X * noise
#       8     return X
#
# File /mnt/c/Users/PC/Documents/Dan/aboutpaperreviews/semi-supervised learning/.cgm/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /mnt/c/Users/PC/Documents/Dan/aboutpaperreviews/semi-supervised learning/.cgm/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py:1264, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1262 # Fallback dispatch system (dispatch v1):
#    1263 try:
# -> 1264   return dispatch_target(*args, **kwargs)
#    1265 except (TypeError, ValueError):
#    1266   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267   # TypeError, when given unexpected types.  So we need to catch both.
#    1268   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /mnt/c/Users/PC/Documents/Dan/aboutpaperreviews/semi-supervised learning/.cgm/lib/python3.12/site-packages/tensorflow/python/ops/math_ops.py:1053, in cast(x, dtype, name)
#    1046     logging.warn(
#    1047         f"You are casting an input of type {x.dtype.name} to an "
#    1048         f"incompatible dtype {base_type.name}.  This will "
#    1049         "discard the imaginary part and may not be what you "
#    1050         "intended."
#    1051     )
#    1052   if x.dtype != base_type:
# -> 1053     x = gen_math_ops.cast(x, base_type, name=name)
#    1054 return x
#
# File /mnt/c/Users/PC/Documents/Dan/aboutpaperreviews/semi-supervised learning/.cgm/lib/python3.12/site-packages/tensorflow/python/ops/gen_math_ops.py:2118, in cast(x, DstT, Truncate, name)
#    2114         _ctx, "Cast", name, x, "DstT", DstT, "Truncate", Truncate)
#    2115       return _result
#    2116     except _core._NotOkStatusException as e:
#    2117       _ops.raise_from_not_ok_status(e, name)
# -> 2118     except _core._FallbackException:
#    2119       pass
#    2120     try:
#    2121       return cast_eager_fallback(
#
# File /mnt/c/Users/PC/Documents/Dan/aboutpaperreviews/semi-supervised learning/.cgm/lib/python3.12/site-packages/tensorflow/python/eager/core.py:42, in _NotOkStatusException.__init__(self, message, code, payloads)
#      39 class _NotOkStatusException(Exception):
#      40   """Exception class to handle not ok Status."""
# ---> 42   def __init__(self, message, code, payloads):
#      43     super(_NotOkStatusException, self).__init__()
#      44     self.message = message
#
# KeyboardInterrupt:
# Normalization failed: type=_NotOkStatusException args=('{{function_node __wrapped__Cast_device_/job:localhost/replica:0/task:0/device:GPU:0}} failed to allocate memory [Op:Cast]', 8, {})

# %%
x_unlabeled_train = tf.concat((X_unlab_change, X_ulb_change_tensor),0)
x_unlabeled_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 x_unlabeled_train = tf.concat((X_unlab_change, X_ulb_change_tensor),0)
#       2 x_unlabeled_train.shape
#
# NameError: name 'X_unlab_change' is not defined

# %%
y_train_tensor = tf.convert_to_tensor(combined_label_train)
print(y_train_tensor.shape)
print(type(y_train_tensor))
# Out:
# (0, 5)
# <class 'tensorflow.python.framework.ops.EagerTensor'>

# %%
print(combined_X_test.shape)
X_test_tensor = tf.convert_to_tensor(combined_X_test)
print(type(X_test_tensor))
# Out:
# (255600, 128)
# <class 'tensorflow.python.framework.ops.EagerTensor'>

# %%
print(combined_label_test.shape)
y_test_tensor = tf.convert_to_tensor(combined_label_test)
print(type(y_test_tensor))
y_test = tf.math.argmax(y_test_tensor,1)
y_test
# Out:
# (255600, 5)
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# <tf.Tensor: shape=(255600,), dtype=int64, numpy=array([0, 0, 0, ..., 4, 4, 4], shape=(255600,))>

# %%
# Define the batch size
DATASET_UNLABELED_SIZE = x_unlabeled_train.shape[0]
DATASET_LABELED_SIZE = X_label_tensor.shape[0]
unlabeled_batch_size = 25
labeled_batch_size = 10
steps_per_epoch = DATASET_LABELED_SIZE//labeled_batch_size
total_steps = EPOCHS * steps_per_epoch
print(f"Batch size: {unlabeled_batch_size} (unlabeled) + {labeled_batch_size} (labeled)")

# Load the unlabeled and labeled samples for training
unlabeled_train= tf.data.Dataset.from_tensor_slices(x_unlabeled_train)
unlabeled_train = (
    unlabeled_train.shuffle(buffer_size=5 * unlabeled_batch_size)
    .batch(unlabeled_batch_size)
    
)

# Convert labels to one-hot vectors              
labeled_train = tf.data.Dataset.from_tensor_slices((X_label_tensor,y_train_tensor))
labeled_train = (
    labeled_train.shuffle(buffer_size=5 * labeled_batch_size)
    .batch(labeled_batch_size)   
)

# Load the test samples
test = (
    tf.data.Dataset.from_tensor_slices((X_test_tensor,y_test_tensor))
    .batch(unlabeled_batch_size)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# Combine the labeled and unlabeled samples for training
data = tf.data.Dataset.zip((unlabeled_train, labeled_train)).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Batch size: 25 (unlabeled) + 10 (labeled)

# %%
# Define the batch size
DATASET_UNLABELED_SIZE = x_unlabeled_train.shape[0]
DATASET_LABELED_SIZE = X_label_tensor.shape[0]
unlabeled_batch_size = 25
labeled_batch_size = 10
steps_per_epoch = DATASET_LABELED_SIZE//labeled_batch_size
total_steps = EPOCHS * steps_per_epoch
print(f"Batch size: {unlabeled_batch_size} (unlabeled) + {labeled_batch_size} (labeled)")

# Load the unlabeled and labeled samples for training
unlabeled_train= tf.data.Dataset.from_tensor_slices(x_unlabeled_train)
unlabeled_train = (
    unlabeled_train.shuffle(buffer_size=5 * unlabeled_batch_size)
    .batch(unlabeled_batch_size)
    
)

# Convert labels to one-hot vectors              
labeled_train = tf.data.Dataset.from_tensor_slices((X_label_tensor,y_train_tensor))
labeled_train = (
    labeled_train.shuffle(buffer_size=5 * labeled_batch_size)
    .batch(labeled_batch_size)   
)

# Load the test samples
test = (
    tf.data.Dataset.from_tensor_slices((X_test_tensor,y_test))
    .batch(unlabeled_batch_size)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# Combine the labeled and unlabeled samples for training
data = tf.data.Dataset.zip((unlabeled_train, labeled_train)).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Batch size: 25 (unlabeled) + 10 (labeled)

# %%
data

# %% [markdown]
# # Define the CNN architecture and Baseline model

# %%
def create_custom_model(input_shape, num_classes):
    # Define the input layer with the specified shape
    inputs = Input(shape=input_shape, name='input')
    
    # Convolutional layers
    x = Conv2D(16, (3, 3), activation='relu', padding='same', name='conv2d_1')(inputs)
    x = MaxPooling2D((2, 2), name='maxpooling_1')(x)
    # x = Dropout(0.3)(x)
    
    x = Conv2D(8, (3, 3), activation='relu', padding='same', name='conv2d_2')(x)
    x = MaxPooling2D((2, 2), name='maxpooling_2')(x)
    
    # Flatten the output
    x = Flatten(name='Flatten')(x)

    # # # Dense layers
    x = Dropout(0.3)(x)
    x = Dense(64, activation='relu', name='Dense_0')(x)

    x = Dropout(0.2)(x)
    
    # Output layer with softmax activation for multi-class classification
    outputs = Dense(num_classes,kernel_regularizer=regularizers.l2(WEIGHT_DECAY),name='output')(x)

    # Create the model by specifying inputs and outputs
    model = Model(inputs=inputs, outputs=outputs, name='Custom_model')
    
    return model

# %%
input_shape= (3600, 128, 1)
num_classes = 5  
custom_model = create_custom_model(input_shape, num_classes)
custom_model.summary()
# Out:
# W0000 00:00:1780389650.749200    6312 nvptx_libdevice_path.cc:41] Can't find libdevice directory ${CUDA_DIR}/nvvm/libdevice. This may result in compilation or runtime failures, if the program we try to run uses routines from libdevice.
# Searched for CUDA in the following directories:
#   ./cuda_sdk_lib
#   ipykernel_launcher.runfiles/cuda_nvcc
#   ipykernel_launcher.runfiles/cuda_nvdisasm
#   ipykernel_launcher.runfiles/nvidia_nvshmem
#   ipykernel_launcher.runfiles/cuda_nvvm
#   ipykernel_launcher.runfiles/cuda_cudart
#   /usr/local/cuda
#   /opt/cuda
#   /mnt/c/Users/PC/Documents/Dan/aboutpaperreviews/semi-supervised learning/.cgm/lib/python3.12/site-packages/tensorflow/python/platform/../../../nvidia/cuda_nvcc
#   /mnt/c/Users/PC/Documents/Dan/aboutpaperreviews/semi-supervised learning/.cgm/lib/python3.12/site-packages/tensorflow/python/platform/../../../../nvidia/cuda_nvcc
#   /mnt/c/Users/PC/Documents/Dan/aboutpaperreviews/semi-supervised learning/.cgm/lib/python3.12/site-packages/tensorflow/python/platform/../../cuda
#   /mnt/c/Users/PC/Documents/Dan/aboutpaperreviews/semi-supervised learning/.cgm/lib/python3.12/site-packages/tensorflow/python/platform/../../../../../..
#   /mnt/c/Users/PC/Documents/Dan/aboutpaperreviews/semi-supervised learning/.cgm/lib/python3.12/site-packages/tensorflow/python/platform/../../../../../../..
#   .
# You can choose the search directory by setting xla_gpu_cuda_data_dir in HloModule's DebugOptions.  For most apps, setting the environment variable XLA_FLAGS=--xla_gpu_cuda_data_dir=/path/to/cuda will work.
# Model: "Custom_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 3600, 128, 1)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 3600, 128, 16)  │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpooling_1 (MaxPooling2D)     │ (None, 1800, 64, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 1800, 64, 8)    │         1,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpooling_2 (MaxPooling2D)     │ (None, 900, 32, 8)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flatten (Flatten)               │ (None, 230400)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 230400)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_0 (Dense)                 │ (None, 64)             │    14,745,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,747,309 (56.26 MB)
#  Trainable params: 14,747,309 (56.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Loss computation utilities

# %%
def compute_supervised_loss(y_labeled, y_predicted):
    loss_func = keras.losses.CategoricalCrossentropy(from_logits=True)
    supervised_loss = loss_func(y_labeled, y_predicted)
    return supervised_loss


def compute_unsupervised_loss(pseudo_labels, unlabeled_data_s, mask):
    loss_func = keras.losses.CategoricalCrossentropy(from_logits=True, reduction="none")
    # Do not update weight during training
    pseudo_labels = tf.stop_gradient(pseudo_labels)
    unsupervised_loss = loss_func(pseudo_labels, unlabeled_data_s)
    mask = tf.cast(mask, unsupervised_loss.dtype)
    unsupervised_loss *= mask
    return tf.reduce_mean(unsupervised_loss,0)

# %% [markdown]
# # Fixmatch model

# %%
class FixMatch(keras.Model):
    def __init__(self,model,total_steps,tau = 0.9):
        super().__init__()
        self.model = model
        # Denotes the confidence threshold
        self.tau = tau             
        self.loss_tracker = tf.keras.metrics.Mean(name="loss")
        self.total_steps = total_steps
        self.current_step = tf.Variable(0,dtype="int64")
        
    @property
    def metrics(self):
        return [self.loss_tracker]

    def compute_mu(self):
        pi = tf.constant(np.pi, dtype="float32")
        step = tf.cast(self.current_step, dtype="float32")
        return 0.5 - tf.cos(tf.math.minimum(pi,(2*pi*step)/self.total_steps)) / 2

    def call(self, inputs, training=False):
        # Forward pass through our custom model
        return self.model(inputs, training=training)
        
    def train_step(self,data):
        unlabeled, (X_labeled, y_labeled) = data
        unlabeled = tf.cast(unlabeled, dtype=tf.float32)
        X_labeled = tf.cast(X_labeled, dtype=tf.float32)

        # Apply two different augmentation methods for input data
        labeled_dataset_w = scale_noise(X_labeled)
        unlabeled_dataset_w = random_crop(unlabeled)
        unlabeled_dataset_s = scale_noise(unlabeled)
          
        combined_data = tf.concat([labeled_dataset_w, unlabeled_dataset_w, unlabeled_dataset_s],0)
        total_labeled_data = tf.shape(labeled_dataset_w)[0]
        total_unlabeled_data = tf.shape(tf.concat([unlabeled_dataset_w, unlabeled_dataset_s], 0))[0]
   
        with tf.GradientTape() as tape:
             # Forward passes
            combined_logits = self.model(combined_data, training=True)
            z_d_prime_labeled_data = self.model(labeled_dataset_w, training=False)
            z_prime_labeled_data = combined_logits[:total_labeled_data]

            # Random logit interpolation for the labeled data
            lambd = tf.random.uniform((total_labeled_data, 5), 0, 1)
            final_labeled_data_logits = (lambd * z_prime_labeled_data) + ((1 - lambd) * z_d_prime_labeled_data)

            # Compute softmax for logits of the weakly augmented labeled data
            y_hat_labeled_data_w = tf.nn.softmax(final_labeled_data_logits[:tf.shape(labeled_dataset_w)[0]])

            # Extract logits for the weakly augmented unlabeled data
            logits_unlabeled = combined_logits[total_labeled_data:]
            logits_unlabeled_w = logits_unlabeled[:tf.shape(unlabeled_dataset_w)[0]]

            y_hat_unlabeled_data_w = tf.nn.softmax(logits_unlabeled_w)

            # Distribution alignment (only consider weakly augmented data)
            # Align the predicted label distribution to that of label data
            expectation_ratio = tf.reduce_mean(y_hat_unlabeled_data_w) / tf.reduce_mean(y_hat_labeled_data_w)
            y_tilde_unlabeled_data_w = tf.math.l2_normalize(y_hat_unlabeled_data_w * expectation_ratio, 1)
       
            # Relative confidence thresholding
            row_wise_max = tf.reduce_max(y_hat_labeled_data_w, axis=-1)
            final_sum = tf.reduce_mean(row_wise_max, 0)
            c_tau = self.tau * final_sum
            # c_tau = self.tau
            mask = tf.reduce_max(y_tilde_unlabeled_data_w, axis=-1) >= c_tau

            # Supervised loss
            supervised_loss = compute_supervised_loss(y_labeled, final_labeled_data_logits[:tf.shape(labeled_dataset_w)[0]])
            
            # Unsupervised loss
            unsupervised_loss = compute_unsupervised_loss(
                y_hat_unlabeled_data_w,
                logits_unlabeled[tf.shape(y_hat_unlabeled_data_w)[0]:],
                mask
            )
            
            t = self.compute_mu()
            total_loss = supervised_loss + (t * unsupervised_loss)
            self.current_step.assign_add(1) 
            
        gradients = tape.gradient(total_loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.model.trainable_variables))

        self.loss_tracker.update_state(total_loss)
        return {"loss":self.loss_tracker.result()}

# %% [markdown]
# # Instantiate Fixmatch model and compile it

# %%
reduce_lr = keras.optimizers.schedules.CosineDecay(LEARNING_RATE, total_steps , 0.25)
optimizer = keras.optimizers.SGD(reduce_lr, momentum=0.9)

fixmatch_trainer = FixMatch(model=custom_model, total_steps=total_steps)
fixmatch_trainer.compile(optimizer=optimizer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 reduce_lr = keras.optimizers.schedules.CosineDecay(LEARNING_RATE, total_steps , 0.25)
#       2 optimizer = keras.optimizers.SGD(reduce_lr, momentum=0.9)
#       3
#       4 fixmatch_trainer = FixMatch(model=custom_model, total_steps=total_steps)
#
# File /mnt/c/Users/PC/Documents/Dan/aboutpaperreviews/semi-supervised learning/.cgm/lib/python3.12/site-packages/keras/src/optimizers/schedules/learning_rate_schedule.py:690, in CosineDecay.__init__(self, initial_learning_rate, decay_steps, alpha, name, warmup_target, warmup_steps)
#     687 self.warmup_target = warmup_target
#     689 if self.decay_steps <= 0:
# --> 690     raise ValueError(
#     691         "Argument `decay_steps` must be > 0. "
#     692         f"Received: decay_steps={self.decay_steps}"
#     693     )
#
# ValueError: Argument `decay_steps` must be > 0. Received: decay_steps=0

# %% [markdown]
# # Model training

# %%
import os 
checkpoint_path = "training_7/my_checkpoints"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose = 0)

# %%
fixmatch_trainer.fit(data, epochs=EPOCHS, callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/200
# 11/11 [==============================] - 2s 131ms/step - loss: 3.7239
# Epoch 2/200
# 11/11 [==============================] - 1s 129ms/step - loss: 1.6281
# Epoch 3/200
# 11/11 [==============================] - 2s 142ms/step - loss: 0.6743
# Epoch 4/200
# 11/11 [==============================] - 1s 127ms/step - loss: 0.4166
# Epoch 5/200
#  2/11 [====>.........................] - ETA: 1s - loss: 0.2079

# %%
os.listdir(checkpoint_dir)

# %%
# fixmatch_trainer.load_weights(checkpoint_path)

# %% [markdown]
# # Evaluation on the test set

# %%
fixmatch_trained_model = fixmatch_trainer.model
fixmatch_trained_model.compile(metrics=keras.metrics.SparseCategoricalAccuracy())

_, accuracy = fixmatch_trained_model.evaluate(test)
print(f"Accuracy on  test set: {accuracy * 100:.2f}%")

# %%
y_predict = fixmatch_trained_model.predict(X_test_tensor)

# %%
y_predict = np.argmax(y_predict, axis = 1)

# %%
y_test

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
label_names = ['Corona', 'Floating', 'Void', 'Particle', 'Noise']
print(classification_report(y_test, y_predict, target_names =label_names ))

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
figure = confusion_matrix(y_test, y_predict)

# Define class labels
label_names = ['Corona', 'Floating', 'Void', 'Particle', 'Noise']

fig, ax = plt.subplots(figsize=(4, 4))
display = ConfusionMatrixDisplay(figure, display_labels=label_names)
display.plot(cmap=plt.cm.Blues, ax=ax, values_format='d') 

# Rotate x-axis labels for better readability
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Add labels to the axis
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")

# Show the plot
plt.tight_layout()  # Adjust layout for better spacing
# Save the figure after it has been shown
plt.savefig('Confusion_matrix_New2.png', transparent =True,bbox_inches='tight', dpi=350, format='png')
plt.show()
